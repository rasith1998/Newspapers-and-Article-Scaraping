# %% [markdown]
# ### Pacakage Installation

# %%
! pip install newspaper3k
# Out:
# ...
#      ------------------------------------ 211.1/211.1 KB 210.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.4/7.4 MB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ------------------------------------ 151.6/151.6 KB 906.4 kB/s eta 0:00:00
# ...
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# ...
#      -------------------------------------- 81.1/81.1 KB 762.0 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 93.6/93.6 KB 886.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.6/3.6 MB 3.8 MB/s eta 0:00:00
# ...
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# ...
#   Preparing metadata (setup.py): started
# ...

# %%
import requests # for making api requests (get, post, put, delete)
import newspaper 
from newspaper import Article
from newspaper import fulltext

# %%
##Check available Language
newspaper.languages()
# Out:
# Your available languages are:
#
# input code		full name
#   ar			  Arabic
#   be			  Belarusian
#   bg			  Bulgarian
#   da			  Danish
#   de			  German
#   el			  Greek
#   en			  English
#   es			  Spanish
#   et			  Estonian
#   fa			  Persian
#   fi			  Finnish
#   fr			  French
#   he			  Hebrew
#   hi			  Hindi
#   hr			  Croatian
#   hu			  Hungarian
#   id			  Indonesian
#   it			  Italian
#   ja			  Japanese
#   ko			  Korean
#   mk			  Macedonian
#   nb			  Norwegian (Bokmål)
#   nl			  Dutch
#   no			  Norwegian
#   pl			  Polish
#   pt			  Portuguese
#   ro			  Romanian
#   ru			  Russian
#   sl			  Slovenian
#   sr			  Serbian
#   sv			  Swedish
#   sw			  Swahili
#   tr			  Turkish
#   uk			  Ukrainian
#   vi			  Vietnamese
#   zh			  Chinese

# %% [markdown]
# ### Working with Articles

# %%
url = input("Enter url Link:")
# Out:
# Enter url Link:https://towardsdatascience.com/5-data-science-skills-that-will-never-become-outdated-6c9de1e60d88

# %%
article = Article(url)#default lang english #article = Article(url, language='zh')
article.download()#It is not physically download the article

# %%
article.html
# Out:
# '<!doctype html><html lang="en"><head><title data-rh="true">5 Data Science Skills That Will Never Become Outdated | by Madison Hunter | Jul, 2022 | Towards Data Science</title><meta data-rh="true" charset="utf-8"/><meta data-rh="true" name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1"/><meta data-rh="true" name="theme-color" content="#000000"/><meta data-rh="true" name="twitter:app:name:iphone" content="Medium"/><meta data-rh="true" name="twitter:app:id:iphone" content="828256236"/><meta data-rh="true" property="al:ios:app_name" content="Medium"/><meta data-rh="true" property="al:ios:app_store_id" content="828256236"/><meta data-rh="true" property="al:android:package" content="com.medium.reader"/><meta data-rh="true" property="fb:app_id" content="542599432471018"/><meta data-rh="true" property="og:site_name" content="Medium"/><meta data-rh="true" property="og:type" content="article"/><meta data-rh="true" property="article:published_time" cont
# ...

# %% [markdown]
# ## Article Parcing

# %%
article.parse() # processing article to get specific data such as authors, publish_data, images e.t.c

# %%
article.authors
# Out:
# ['Madison Hunter']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
article.publish_date
# Out:
# datetime.datetime(2022, 7, 21, 21, 32, 41, 496000, tzinfo=tzutc())

# %%
article.text
# Out:
# "However, despite all of the things that could happen to the data science field, there are five skills that will remain relevant in the foreseeable future.\n\nOver the years, the programming languages will change, as will the capabilities of machine learning and artificial intelligence. New tools will be created to produce beautiful visualizations. The data pipeline may become so streamlined that one person could carry out the jobs of a data engineer, analyst, and scientist.\n\nWhile we love to discuss the latest trends in data science and the newest technologies that employers are looking for, we don’t always pay as much attention to the skills you will always need, whether you’re a data scientist in 2022 or 2072.\n\nTrends will come and go, but data scientists will always need these skills\n\n1. Remaining relevant by learning new skills on the fly\n\nA data scientist’s worth is decided by the impact they bring to their company. The amount of impact a data scientist can bring to a c
# ...

# %%
article.top_image  #Only Top images
# Out:
# 'https://miro.medium.com/max/1200/0*EF0nVnUpua8vLYz_'

# %%
article.images #All images
# Out:
# {'https://miro.medium.com/fit/c/176/176/1*WE_v8m4E4u_CdWLHwYGP9A.jpeg',
#  'https://miro.medium.com/fit/c/40/40/0*fz81le9wIw71uA8t.',
#  'https://miro.medium.com/fit/c/40/40/0*mVGMYFbKw0jrH0kb',
#  'https://miro.medium.com/fit/c/40/40/1*1PQWvoPNazuD2aYgwsVi4Q.jpeg',
#  'https://miro.medium.com/fit/c/40/40/1*AXtXykgDOsuyiGRk-04GCg.png',
#  'https://miro.medium.com/fit/c/40/40/1*OguCSwREJBOtu8T8zz1Uxg.png',
#  'https://miro.medium.com/fit/c/40/40/1*R76gULg98d2kCqKyqIw2YA@2x.jpeg',
#  'https://miro.medium.com/fit/c/40/40/1*VsqwrNAcO0qJQekfBV-cuA.jpeg',
#  'https://miro.medium.com/fit/c/40/40/1*WE_v8m4E4u_CdWLHwYGP9A.jpeg',
#  'https://miro.medium.com/fit/c/40/40/1*WcTUCggdo4-GV7BBRfFMGA.jpeg',
#  'https://miro.medium.com/fit/c/40/40/1*shqK4mjYM-d5PPQW6F3-Kw.jpeg',
#  'https://miro.medium.com/fit/c/40/40/2*7aiGz-HJPE2PpfBfM0Vgiw.png',
#  'https://miro.medium.com/fit/c/40/40/2*xmanz0nHjUWhZDxHWKKaYg.png',
#  'https://miro.medium.com/fit/c/64/64/1*CJe3891yB1A1mzMdqemkdg.jpeg',
# ...

# %% [markdown]
# ### Article Natural Language Processing

# %%
import nltk
nltk.download('punkt')
article.nlp() # processing natural language based functions to get language based predictions of article
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Rasith\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
article.keywords
# Out:
# ['scientist',
#  'questions',
#  'youre',
#  'science',
#  'data',
#  'skills',
#  'outdated',
#  'scientists',
#  'work',
#  'ability',
#  'relevant']

# %%
article.summary
# Out:
# 'However, despite all of the things that could happen to the data science field, there are five skills that will remain relevant in the foreseeable future.\nFor example, Symon.AI and Obviously.AI are attempting to revolutionize the industry by developing no-code data science capabilities.\nUsing foundational math conceptsMath will never become outdated in data science.\nLuckily, you’ve probably already developed this skill during the process of learning the skills required to become a data scientist.\nOld code always gets passed down to new data scientists who are then tasked with using or perhaps modernizing it.'

# %% [markdown]
# ### Working with Newspapers

# %%
url = input("Enter newspaper URL: ")
# Out:
# Enter newspaper URL: https://www.ft.lk/

# %%
import newspaper
newspaper = newspaper.build(url, memoize_articles=False) ##, language='zh') #memoize_articles=False is for not eleminate

# %%
newspaper.size()# No of news articles
# Out:
# 50

# %%
newspaper.brand # News owner
# Out:
# 'ft'

# %%
newspaper.description
# Out:
# "Latest news, analysis and opinions from the Daily FT, Sri Lanka's latest business updates."

# %%
articles = newspaper.articles # articles present in the newspaper
for article in articles:
    print(article.url)
# Out:
# https://www.ft.lk/news/56
# https://www.ft.lk/news/10526
# https://www.ft.lk/news/Ranil-elected-President/56-737707
# https://www.ft.lk/news/Sri-Lanka-beat-Australia-to-level-Test-series/56-737356
# https://www.ft.lk/news/Election-for-new-President-on-20-July/56-737355
# https://www.ft.lk/news/Colombo-stock-market-gains-on-political-developments/56-737352
# https://www.ft.lk/news/Incumbent-Cabinet-awaits-finality-on-new-all-party-Govt-before-quitting/56-737351
# https://www.ft.lk/news/Apparel-industry-says-Make-Sri-Lanka-First-a-national-priority-and-agenda/56-737290
# https://www.ft.lk/news/Ceylon-Chamber-calls-on-President-to-resign-and-party-leaders-to-ensure-smooth-transition-of-power/56-737289
# https://www.ft.lk/news/President-Gotabaya-to-resign-on-Wednesday/56-737287
# https://www.ft.lk/news/Kanchana-calls-fuel-QR-pilot-system-a-success/56-737770
# https://www.ft.lk/news/ICTA-says-fuel-pass-only-via-official-website/56-737771
# ...

# %%
categories = newspaper.category_urls() # URLs for categories which belongs to the newspaper

# %%
for category in categories:
    print(category)
# Out:
# http://www.ft.lk
# https://www.ft.lk
# https://www.ft.lk/

# %%
feeds = newspaper.feed_urls() # URLs for feeds which available in the newspaper

# %%
for feed in feeds:
    print(feed)

# %%
article = articles[10]

article.download()
article.parse()
article.html
# Out:
# '<!doctype html>\r\n<html lang="en">\r\n<head>\r\n<!-- Required meta tags -->\r\n<meta charset="utf-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\r\n\t\t\t\t\t    <!-- Global Site Tag (gtag.js) - Google Analytics -->\r\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-30012267-1"></script>\r\n<script>\r\n  window.dataLayer = window.dataLayer || [];\r\n  function gtag(){dataLayer.push(arguments);}\r\n  gtag(\'js\', new Date());\r\n\r\n  gtag(\'config\', \'UA-30012267-1\');\r\n</script>\r\n<!-- Bootstrap CSS -->\r\n<link rel="stylesheet" href="https://www.ft.lk/assets/2020/css/bootstrap.min.css">\r\n<link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.6.3/css/all.css" integrity="sha384-UHRtZLI+pbxtHCWp1t77Bi1L4ZtiqrqD80Kn4Z8NTSRyMA2Fd33n5dQ8lWUE00s/" crossorigin="anonymous">\r\n<link rel="stylesheet" href="https://www.ft.lk/assets/2020/css/owl.carousel.min.css">\r\n<link rel="stylesheet" href="https://www.
# ...

# %% [markdown]
# ## HTML to Plain Text

# %%
url = input("Enter any URL: ")
response = requests.get(url) 
html = response.text 
plainText = fulltext(html)
plainText
# Out:
# Enter any URL: https://towardsdatascience.com/5-data-science-skills-that-will-never-become-outdated-6c9de1e60d88
# ...

# %%
import newspaper
newspaper.hot() # getting a list of top trending terms on google using public api
# Out:
# ['Joe Biden',
#  'Donald Trump',
#  'RB Leipzig vs Liverpool',
#  'American Horror Story',
#  'Polio',
#  'Shonka Dukureh',
#  'Ricky Martin',
#  'Kyler Murray',
#  'Does Biden have cancer',
#  'One Medical',
#  'Oppenheimer',
#  'John Carpenter',
#  'Snap Stock',
#  'Dave Chappelle',
#  'Katie Ledecky',
#  "Don't Worry Darling",
#  'Steph Curry',
#  'Liz Cheney',
#  'Robin Williams',
#  'Financial advisor']

# %%
newspaper.popular_urls() # list of latest and popular news source URLs
# Out:
# ['http://www.huffingtonpost.com',
#  'http://cnn.com',
#  'http://www.time.com',
#  'http://www.ted.com',
#  'http://pandodaily.com',
#  'http://www.cnbc.com',
#  'http://www.mlb.com',
#  'http://www.pcmag.com',
#  'http://www.foxnews.com',
#  'http://theatlantic.com',
#  'http://www.bbc.co.uk',
#  'http://www.vice.com',
#  'http://www.elle.com',
#  'http://www.vh1.com',
#  'http://espnf1.com',
#  'http://espn.com',
#  'http://www.npr.org',
#  'http://www.sfgate.com',
#  'http://www.glamour.com',
#  'http://www.whosdatedwho.com',
#  'http://kotaku.com',
#  'http://thebostonchannel.com',
#  'http://www.suntimes.com',
#  'http://www.businessinsider.com',
#  'http://www.rivals.com',
#  'http://thebusinessjournal.com',
#  'http://www.newrepublic.com',
#  'http://allthingsd.com',
#  'http://www.topgear.com',
#  'http://thecitizen.com',
#  'http://www.ign.com',
#  'http://www.sci-news.com',
#  'http://www.morningstar.com',
#  'http://www.variety.com',
# ...

# %% [markdown]
# ### Reference : https://www.youtube.com/watch?v=MC4Y28zWG2M&list=PLufjXhFyfs7f_-PHu2cuKVAQGn3Sx4YZN&index=2
